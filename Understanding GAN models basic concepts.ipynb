# %% [markdown]
# # Deep Learning CW2 exercises

# %% [markdown]
# ## Reference: https://towardsdatascience.com/understanding-generative-adversarial-networks-4dafc963f2ef

# %% [markdown]
# ### 1. What are two basic part in generative model?

# %% [markdown]
# ### 2. What is the specific objective of these two part?

# %% [markdown]
# ### 3. What is the basic loss function of GAN.

# %% [markdown]
# ### 4. What is training process of basic GAN model?

# %% [markdown]
# ## Exercises based on gan_tensorflow.py
# 1.
#     1. Dataset: What is dataset being used? How can you load this dataset?
#     2. Model: Can you plot/draw the basic architecture in this case?
#     3. Loss: What is loss function in this example?
#     4. Training: How is this network being trained?
#     5. Test: How do you test this model?

# %% [markdown]
# * Stating model batch size 100 and learning rate 0.0002 over 100 epocs
# ![train_hist_lr_0.0002_batch_100_e_100.png](attachment:train_hist_lr_0.0002_batch_100_e_100.png)

# %% [markdown]
# * Changing the learning rate to 0.01 results of loss functions over 100 epocs
# ![train_hist_lr_0.01_batch_100_e_100.png](attachment:train_hist_lr_0.01_batch_100_e_100.png)

# %% [markdown]
# * Changing the batch size to 256 (keeping lr=0.0002) results of loss functions over 100 epocs
# ![train_hist_lr_0.0002_batch_256_e_100.png](attachment:train_hist_lr_0.0002_batch_256_e_100.png)

# %% [markdown]
# * Changing the batch size to 256 and learning rate 0.01 results of loss functions over 100 epocs
# ![train_hist_lr_0.01_batch_256_e_100.png](attachment:train_hist_lr_0.01_batch_256_e_100.png)

# %% [markdown]
# * Changing the batch size to 256 (keeping learning rate 0.0002) allowing to run for 200 epocs
# ![train_hist_lr_0.0002_batch_256_e_200.png](attachment:train_hist_lr_0.0002_batch_256_e_200.png)
